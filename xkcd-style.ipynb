# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

x = np.linspace(0, 4, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Fos')
# Out:
# Text(0.5,1,u'Fos')

# %%
plt.xkcd()  # Yes...
plt.plot(x, y)
plt.title('Whoo Hoo!!!')
# Out:
# Text(0.5,1,u'Whoo Hoo!!!')
